# %%
import json
import statistics
for i in range(1, 11):
    with open(f'./fps-data/3d-{i}.json', 'r') as f:
        data = json.load(f)
        frames = data['performance']['flutterFrames']
        durs = [1_000_000/f['elapsed'] for f in frames]

        mean = statistics.mean(durs)
        std_dev = statistics.stdev(durs)
        # print(f'2d-{i}.json')
        # print('Samples:', len(durs))
        # print("Mean:", mean)
        # print("Standard Deviation:", std_dev)
        # print(f'({mean}, {std_dev})')
        # print(f'({i}, {mean}),')
        print(f'  {std_dev},')
        # print()
# Out:
#   7.3809551064869705,
#   4.04374222994692,
#   2.878358926721117,
#   1.7253419280650022,
#   1.3936674541893945,
#   1.0887743459044037,
#   0.8788561624153596,
#   0.7320979208177678,
#   0.5592591875808219,
#   0.5056577586204537,
